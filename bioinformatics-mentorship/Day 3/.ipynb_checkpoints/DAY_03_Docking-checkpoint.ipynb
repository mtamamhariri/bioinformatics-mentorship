# %% [markdown]
# ## Analisis Docking Hari 3
#
# 1.  **Protein Target (Gembok):** Human CDK2 (P24941)
# 2.  **Template PDB:** 1fin.1.A
# 3.  **Obat (Kunci):** Staurosporine
# 4.  **Hasil Docking (Skor):** -6.2840 (dari Cluster 7)

# %%
import nglview as nv
from IPython.display import display

# 1. Menampilkan "Gembok" (Protein)
view = nv.show_file("cdk2_model.pdb", ext="pdb")

# 2. Menambahkan "Kunci" (Ligan)
view2 = nv.show_file("cluster.7.pdb", ext="pdb")

# 3. Menggabungkan tampilan menggunakan add_representation pada masing-masing struktur
view.add_representation("cartoon", selection="protein")
view.add_representation("ball+stick", selection="not protein and not water")

# 4. Menambahkan view2 ke dalam tampilan view utama dengan fungsi display()
display(view)

# Menampilkan objek
view.add_representation('cartoon', selection='protein')
view.add_representation('ball+stick', selection='not protein and not water')
# Out:
# NGLWidget()
