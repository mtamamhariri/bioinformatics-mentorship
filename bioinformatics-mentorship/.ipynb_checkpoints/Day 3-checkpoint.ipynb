# %%
import nglview as nv
from IPython.display import display

# 1. Muat "Gembok" (Protein)
view = nv.show_file("cdk2_model.pdb", ext="pdb")

# 2. Tambahkan "Kunci" (Ligan)
view.add_file("cluster.7.pdb", ext="pdb")

# 3. Atur Tampilan
view.clear_representations()
view.add_representation('cartoon', selection='protein')
view.add_representation('ball+stick', selection='not protein and not water')

# 4. Tampilkan!
display(view)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import nglview as nv
#       2 from IPython.display import display
#       4 # 1. Muat "Gembok" (Protein)
#
# ModuleNotFoundError: No module named 'nglview'
