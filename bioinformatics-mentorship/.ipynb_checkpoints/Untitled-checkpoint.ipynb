# %%
import nglview as nv
from IPython.display import display

# 1. Muat "Gembok" (Protein)
view = nv.show_file("cdk2_model.pdb", ext="pdb")

# 2. Tambahkan "Kunci" (Ligan)
view.add_component("cluster.7.pdb", ext="pdb")

# 3. Atur Tampilan
view.clear_representations()
view.add_representation('cartoon', selection='protein')
view.add_representation('ball+stick', selection='not protein and not water')

# 4. Tampilkan!
display(view)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 8
#       5 view = nv.show_file("cdk2_model.pdb", ext="pdb")
#       7 # 2. Tambahkan "Kunci" (Ligan)
# ----> 8 view.add_file("cluster.7.pdb", ext="pdb")
#      10 # 3. Atur Tampilan
#      11 view.clear_representations()
#
# AttributeError: 'NGLWidget' object has no attribute 'add_file'
