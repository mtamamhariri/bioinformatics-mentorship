# %%
import pandas
import Bio
print("Lingkungan Kerja Siap!")
# Out:
# Lingkungan Kerja Siap!

# %% [markdown]
# 1: Mengapa Anda (sebagai ilmuwan) harus menggunakan Conda?

# %% [markdown]
# 2: Mengapa Anda (sebagai ilmuwan) harus menggunakan Git?
